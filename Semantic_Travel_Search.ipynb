# %% [markdown]
# <a href="https://colab.research.google.com/github/limysh/AI-Engineer-Learnings/blob/main/Semantic_Travel_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RAG-Ready Semantic Search Demo

# %%
# !pip install openai pymongo python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 15.1 MB/s eta 0:00:00
# ...

# %%
import os

from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# %%
from pymongo import MongoClient

from urllib.parse import quote_plus
from google.colab import userdata

username = "limysh-rag"
password = quote_plus(userdata.get('MONGO_PASSWORD'))

MONGO_URI = f"mongodb+srv://{username}:{password}@cluster0.ptlh030.mongodb.net/"


client = MongoClient(MONGO_URI)

db = client["semantic_search_db"]
collection = db["travel_notes"]

# %%
travel_notes = [
    {
        "text": "Moraine Lake sunrise was breathtaking and the hiking trails were beautiful."
    },
    {
        "text": "Tokyo subway navigation was confusing at first but very efficient."
    },
    {
        "text": "Cape Breton Cabot Trail had stunning ocean cliffs and scenic drives."
    },
    {
        "text": "Banff National Park offered incredible mountain hiking experiences."
    },
    {
        "text": "The cafes in Montreal had amazing pastries and coffee culture."
    }
]

# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
def get_embedding(text):
    response = openai_client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )

    return response.data[0].embedding

# %%
embedding = get_embedding(travel_notes[0]["text"])

print(len(embedding))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_7855/528271849.py in <cell line: 0>()
# ----> 1 embedding = get_embedding(travel_notes[0]["text"])
#       2
#       3 print(len(embedding))
#
# /tmp/ipykernel_7855/845775108.py in get_embedding(text)
#       1 def get_embedding(text):
# ----> 2     response = openai_client.embeddings.create(
#       3         model="text-embedding-3-small",
#       4         input=text
#       5     )
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/embeddings.py in create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     134             return obj
#     135
# --> 136         return self._post(
#     137             "/embeddings",
#     138             body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#
# ...
